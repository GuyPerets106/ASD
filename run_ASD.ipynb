# %% [markdown]
# ## Choose the attack and GPU to run on

# %%
ATTACK_TYPE = "sig_test"  # Options: "sig_test", "invisible_grid_attack", "smooth_poison"
GPU_ID = "0"  # Change this to select GPU

# %% [markdown]
# ## Setup

# %%
import subprocess

config_name = {
    "SIG": "sig_test",
    "invisible_grid": "invisible_grid_attack",
    "smooth_poison": "smooth_poison"
}.get(ATTACK_TYPE, "sig_attack")

config_path_example = "./config/sig_test_20_6.yaml" # Change this to the path of the config file

def run_training():
    print(f"\n🚀 Starting training for {ATTACK_TYPE} attack...\n")
    command = f"python ASD.py --config {config_path_example} --resume False --gpu {GPU_ID}" # Change this to the paths accordingly
    process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    for line in iter(process.stdout.readline, b''):
        print(line.decode(), end='')
    process.stdout.close()
    process.wait()
    print("✅ Training completed!")

def run_testing(model_path, config_path):
    command = f"python test.py --config {config_path} --resume {model_path} --gpu {GPU_ID}"
    process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    for line in iter(process.stdout.readline, b''):
        print(line.decode(), end='')
    process.stdout.close()
    process.wait()
    print("✅ Testing completed!\n")

# %% [markdown]
# ## Training

# %%
run_training()
# Out:
# 🚀 Starting training for sig_test attack...
# ===Setup running===
# Delete existing /gpfs0/bgu-benshimo/users/guyperet/ASD/saved_data/sig_test_20_6 for not resuming.
# Delete existing /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6 for not resuming.
# Training on a single GPU: 0.
# Start at: Sat Feb  1 08:54:06 2025 at: vscode-guy-0-8
# ===Prepare data===
# Load backdoor config:
# {'amp': 30, 'freq': 6, 'poison_ratio': 0.05, 'target_label': 3, 'SIG': True}
# Training transformations:
#  {'pre': Compose(
# ), 'primary': Compose(
#     RandomCrop(size=(32, 32), padding=4)
#     RandomHorizontalFlip(p=0.5)
# ), 'remaining': Compose(
#     ToTensor()
#     Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.201])
# )}
# Test transformations:
#  {'pre': Compose(
# ), 'primary': Compose(
# ), 'remaining': Compose(
#     ToTensor()
#     Normalize(mean=[0.4914, 0.4822, 0.4465], std=[0.2023, 0.1994, 0.201])
# )}
# Load dataset from: /gpfs0/bgu-benshimo/users/guyperet/ASD/datasets/cifar-10/cifar-10-batches-py
# Save poisoned index to /gpfs0/bgu-benshimo/users/guyperet/ASD/saved_data/sig_test_20_6/poison_idx.npy
#
# ===Setup training===
# Create network: {'resnet18_cifar': {'num_classes': 10}}
# Create criterion: CrossEntropyLoss() for test
# Create criterion: SCELoss() for data split
# Create criterion: MixMatchLoss() for semi-training
# Create optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.002
#     weight_decay: 0
# )
# Create scheduler: None
# Training from scratch.
# ===Epoch: 1/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/100.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 2.29424 | 2.29424 | 0.00774 |    0.00000 |
# | 341/1024    | 0.69891 | 0.69855 | 0.00862 |    0.04163 |
# | 682/1024    | 0.46987 | 0.46923 | 0.00764 |    0.08325 |
# | 1023/1024   | 0.89979 | 0.89857 | 0.00977 |    0.12488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 1.02014 | 1.01942 | 0.01196 |    0.06244 | 509.71014 |
# Test model on clean data...
# Clean Data Model Accuracy: 33.51%%
# Test model on poison data...
# Attack Success Rate: 0.43%%
# Best test accuaracy 0.33514636075949367 in epoch 1
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 1 took 554.9085659980774 seconds
# ===Epoch: 2/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/100.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.09649 | 1.09505 | 0.01153 |    0.12500 |
# | 341/1024    | 1.29646 | 1.29378 | 0.01604 |    0.16663 |
# | 682/1024    | 0.66330 | 0.66184 | 0.00704 |    0.20825 |
# | 1023/1024   | 1.09825 | 1.09512 | 0.01252 |    0.24988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.84634 | 0.84434 | 0.01067 |    0.18744 | 496.80436 |
# Test model on clean data...
# Clean Data Model Accuracy: 35.96%%
# Test model on poison data...
# Attack Success Rate: 0.04%%
# Best test accuaracy 0.35957278481012656 in epoch 2
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 2 took 538.4941375255585 seconds
# ===Epoch: 3/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/100.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.75415 | 0.75238 | 0.00708 |    0.25000 |
# | 341/1024    | 1.05874 | 1.05505 | 0.01263 |    0.29163 |
# | 682/1024    | 0.37061 | 0.36846 | 0.00644 |    0.33325 |
# | 1023/1024   | 1.15338 | 1.14794 | 0.01450 |    0.37488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.80020 | 0.79686 | 0.01067 |    0.31244 | 493.96922 |
# Test model on clean data...
# Clean Data Model Accuracy: 38.19%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.3819224683544304 in epoch 3
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 3 took 535.5075764656067 seconds
# ===Epoch: 4/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/100.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.62656 | 0.62363 | 0.00781 |    0.37500 |
# | 341/1024    | 0.38854 | 0.38618 | 0.00565 |    0.41663 |
# | 682/1024    | 1.00586 | 1.00045 | 0.01180 |    0.45825 |
# | 1023/1024   | 0.55242 | 0.54773 | 0.00938 |    0.49988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.76427 | 0.75943 | 0.01106 |    0.43744 | 460.36430 |
# Test model on clean data...
# Clean Data Model Accuracy: 39.66%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.39655854430379744 in epoch 4
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 4 took 501.225460767746 seconds
# ===Epoch: 5/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/100.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.43200 | 0.42838 | 0.00725 |    0.50000 |
# | 341/1024    | 0.72482 | 0.71975 | 0.00935 |    0.54163 |
# | 682/1024    | 1.04255 | 1.03495 | 0.01304 |    0.58325 |
# | 1023/1024   | 0.24908 | 0.24467 | 0.00706 |    0.62488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.73780 | 0.73131 | 0.01152 |    0.56244 | 462.39274 |
# Test model on clean data...
# Clean Data Model Accuracy: 41.62%%
# Test model on poison data...
# Attack Success Rate: 0.26%%
# Best test accuaracy 0.4162381329113924 in epoch 5
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 5 took 503.1500539779663 seconds
# ===Epoch: 6/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/200.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.66184 | 0.65580 | 0.00966 |    0.62500 |
# | 341/1024    | 0.93221 | 0.92376 | 0.01268 |    0.66663 |
# | 682/1024    | 0.94847 | 0.93892 | 0.01349 |    0.70825 |
# | 1023/1024   | 0.06832 | 0.06330 | 0.00669 |    0.74988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.73275 | 0.72448 | 0.01202 |    0.68744 | 175.00558 |
# Test model on clean data...
# Clean Data Model Accuracy: 45.97%%
# Test model on poison data...
# Attack Success Rate: 0.02%%
# Best test accuaracy 0.4596518987341772 in epoch 6
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 6 took 216.20336198806763 seconds
# ===Epoch: 7/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/200.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.56167 | 0.55512 | 0.00873 |    0.75000 |
# | 341/1024    | 0.90430 | 0.89064 | 0.01726 |    0.79163 |
# | 682/1024    | 1.04264 | 1.02766 | 0.01798 |    0.83325 |
# | 1023/1024   | 0.62449 | 0.61416 | 0.01181 |    0.87488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.69982 | 0.68980 | 0.01231 |    0.81244 | 174.63320 |
# Test model on clean data...
# Clean Data Model Accuracy: 46.94%%
# Test model on poison data...
# Attack Success Rate: 0.13%%
# Best test accuaracy 0.46944224683544306 in epoch 7
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 7 took 215.38845252990723 seconds
# ===Epoch: 8/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/200.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.54623 | 0.53878 | 0.00851 |    0.87500 |
# | 341/1024    | 0.92843 | 0.91599 | 0.01357 |    0.91663 |
# | 682/1024    | 0.86450 | 0.84826 | 0.01694 |    0.95825 |
# | 1023/1024   | 1.07601 | 1.05987 | 0.01614 |    0.99988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.71282 | 0.70089 | 0.01273 |    0.93744 | 174.82558 |
# Test model on clean data...
# Clean Data Model Accuracy: 48.89%%
# Test model on poison data...
# Attack Success Rate: 0.63%%
# Best test accuaracy 0.4889240506329114 in epoch 8
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 8 took 215.84590125083923 seconds
# ===Epoch: 9/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/200.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.76167 | 0.75086 | 0.01082 |    1.00000 |
# | 341/1024    | 0.89232 | 0.87690 | 0.01481 |    1.04163 |
# | 682/1024    | 0.92209 | 0.90424 | 0.01648 |    1.08325 |
# | 1023/1024   | 1.01007 | 0.99125 | 0.01673 |    1.12488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.69151 | 0.67821 | 0.01252 |    1.06244 | 174.55948 |
# Test model on clean data...
# Clean Data Model Accuracy: 50.63%%
# Test model on poison data...
# Attack Success Rate: 0.62%%
# Best test accuaracy 0.5063291139240507 in epoch 9
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 9 took 215.54839086532593 seconds
# ===Epoch: 10/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/200.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.85551 | 0.83911 | 0.01458 |    1.12500 |
# | 341/1024    | 0.04880 | 0.04226 | 0.00561 |    1.16663 |
# | 682/1024    | 0.40445 | 0.39625 | 0.00678 |    1.20825 |
# | 1023/1024   | 0.80655 | 0.78753 | 0.01521 |    1.24988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.69336 | 0.67841 | 0.01259 |    1.18744 | 176.86623 |
# Test model on clean data...
# Clean Data Model Accuracy: 49.55%%
# Test model on poison data...
# Attack Success Rate: 2.12%%
# Best test accuaracy 0.5063291139240507 in epoch 9
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 10 took 217.7088599205017 seconds
# ===Epoch: 11/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/300.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.16046 | 0.15386 | 0.00528 |    1.25000 |
# | 341/1024    | 1.02242 | 1.00243 | 0.01547 |    1.29163 |
# | 682/1024    | 0.73482 | 0.71660 | 0.01367 |    1.33325 |
# | 1023/1024   | 0.94818 | 0.92539 | 0.01657 |    1.37488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.66872 | 0.65258 | 0.01230 |    1.31244 | 144.39592 |
# Test model on clean data...
# Clean Data Model Accuracy: 51.23%%
# Test model on poison data...
# Attack Success Rate: 0.13%%
# Best test accuaracy 0.5122626582278481 in epoch 11
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 11 took 185.17722272872925 seconds
# ===Epoch: 12/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/300.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.39923 | 0.38879 | 0.00759 |    1.37500 |
# | 341/1024    | 1.01664 | 0.99611 | 0.01450 |    1.41663 |
# | 682/1024    | 0.65907 | 0.63728 | 0.01495 |    1.45825 |
# | 1023/1024   | 0.85464 | 0.83384 | 0.01387 |    1.49988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.68149 | 0.66375 | 0.01234 |    1.43744 | 143.91358 |
# Test model on clean data...
# Clean Data Model Accuracy: 51.74%%
# Test model on poison data...
# Attack Success Rate: 0.09%%
# Best test accuaracy 0.5174050632911392 in epoch 12
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 12 took 184.74235844612122 seconds
# ===Epoch: 13/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/300.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.61875 | 0.60603 | 0.00848 |    1.50000 |
# | 341/1024    | 0.95019 | 0.92227 | 0.01811 |    1.54163 |
# | 682/1024    | 0.61712 | 0.60091 | 0.01024 |    1.58325 |
# | 1023/1024   | 0.79230 | 0.76848 | 0.01465 |    1.62488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.67589 | 0.65685 | 0.01219 |    1.56244 | 144.59411 |
# Test model on clean data...
# Clean Data Model Accuracy: 51.63%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.5174050632911392 in epoch 12
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 13 took 185.2064118385315 seconds
# ===Epoch: 14/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/300.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.14961 | 0.14283 | 0.00417 |    1.62500 |
# | 341/1024    | 0.50762 | 0.49569 | 0.00716 |    1.66663 |
# | 682/1024    | 0.76993 | 0.74571 | 0.01418 |    1.70825 |
# | 1023/1024   | 0.61354 | 0.58849 | 0.01431 |    1.74988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.66298 | 0.64273 | 0.01200 |    1.68744 | 145.20825 |
# Test model on clean data...
# Clean Data Model Accuracy: 53.06%%
# Test model on poison data...
# Attack Success Rate: 0.07%%
# Best test accuaracy 0.530557753164557 in epoch 14
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 14 took 185.88021898269653 seconds
# ===Epoch: 15/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/300.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.21425 | 1.18293 | 0.01790 |    1.75000 |
# | 341/1024    | 0.23367 | 0.22399 | 0.00541 |    1.79163 |
# | 682/1024    | 0.54840 | 0.53005 | 0.01001 |    1.83325 |
# | 1023/1024   | 0.76274 | 0.73964 | 0.01232 |    1.87488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.68894 | 0.66702 | 0.01209 |    1.81244 | 144.15933 |
# Test model on clean data...
# Clean Data Model Accuracy: 55.89%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.5589398734177216 in epoch 15
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 15 took 184.7953646183014 seconds
# ===Epoch: 16/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/400.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.13598 | 0.12450 | 0.00612 |    1.87500 |
# | 341/1024    | 0.65711 | 0.63964 | 0.00911 |    1.91663 |
# | 682/1024    | 0.94295 | 0.90991 | 0.01687 |    1.95825 |
# | 1023/1024   | 0.89792 | 0.86773 | 0.01510 |    1.99988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.70239 | 0.67872 | 0.01222 |    1.93744 | 118.50518 |
# Test model on clean data...
# Clean Data Model Accuracy: 53.46%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.5589398734177216 in epoch 15
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 16 took 159.28265118598938 seconds
# ===Epoch: 17/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/400.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.80932 | 0.78161 | 0.01385 |    2.00000 |
# | 341/1024    | 1.03100 | 1.00330 | 0.01357 |    2.04163 |
# | 682/1024    | 0.70982 | 0.68316 | 0.01280 |    2.08325 |
# | 1023/1024   | 1.08976 | 1.06019 | 0.01391 |    2.12488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.67715 | 0.65256 | 0.01192 |    2.06244 | 118.83425 |
# Test model on clean data...
# Clean Data Model Accuracy: 54.22%%
# Test model on poison data...
# Attack Success Rate: 0.01%%
# Best test accuaracy 0.5589398734177216 in epoch 15
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 17 took 159.5183346271515 seconds
# ===Epoch: 18/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/400.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.67680 | 0.65665 | 0.00949 |    2.12500 |
# | 341/1024    | 0.03738 | 0.02525 | 0.00560 |    2.16663 |
# | 682/1024    | 0.18955 | 0.18101 | 0.00387 |    2.20825 |
# | 1023/1024   | 0.94132 | 0.90792 | 0.01485 |    2.24988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.64798 | 0.62248 | 0.01166 |    2.18744 | 120.27458 |
# Test model on clean data...
# Clean Data Model Accuracy: 55.53%%
# Test model on poison data...
# Attack Success Rate: 0.01%%
# Best test accuaracy 0.5589398734177216 in epoch 15
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 18 took 161.0938000679016 seconds
# ===Epoch: 19/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/400.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.03319 | 0.99794 | 0.01567 |    2.25000 |
# | 341/1024    | 0.57292 | 0.54893 | 0.01047 |    2.29163 |
# | 682/1024    | 0.35407 | 0.34039 | 0.00586 |    2.33325 |
# | 1023/1024   | 0.57482 | 0.55390 | 0.00881 |    2.37488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.65204 | 0.62539 | 0.01152 |    2.31244 | 117.52909 |
# Test model on clean data...
# Clean Data Model Accuracy: 55.85%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.5589398734177216 in epoch 15
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 19 took 158.26466155052185 seconds
# ===Epoch: 20/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/400.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.85812 | 0.82339 | 0.01462 |    2.37500 |
# | 341/1024    | 1.03141 | 0.99624 | 0.01456 |    2.41663 |
# | 682/1024    | 0.69514 | 0.67050 | 0.01002 |    2.45825 |
# | 1023/1024   | 0.53497 | 0.51422 | 0.00830 |    2.49988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.66336 | 0.63558 | 0.01140 |    2.43744 | 118.98219 |
# Test model on clean data...
# Clean Data Model Accuracy: 57.01%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.5701147151898734 in epoch 20
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 20 took 159.65194249153137 seconds
# ===Epoch: 21/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/500.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.11897 | 1.07773 | 0.01650 |    2.50000 |
# | 341/1024    | 1.02695 | 0.98756 | 0.01550 |    2.54163 |
# | 682/1024    | 0.62938 | 0.60681 | 0.00874 |    2.58325 |
# | 1023/1024   | 0.75570 | 0.72540 | 0.01154 |    2.62488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.69895 | 0.66919 | 0.01162 |    2.56244 | 106.57972 |
# Test model on clean data...
# Clean Data Model Accuracy: 59.50%%
# Test model on poison data...
# Attack Success Rate: 0.01%%
# Best test accuaracy 0.5950356012658228 in epoch 21
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 21 took 147.32558727264404 seconds
# ===Epoch: 22/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/500.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.14448 | 1.10511 | 0.01500 |    2.62500 |
# | 341/1024    | 0.78462 | 0.74966 | 0.01311 |    2.66663 |
# | 682/1024    | 0.40948 | 0.39627 | 0.00488 |    2.70825 |
# | 1023/1024   | 0.07619 | 0.06616 | 0.00365 |    2.74988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.68502 | 0.65516 | 0.01111 |    2.68744 | 108.42857 |
# Test model on clean data...
# Clean Data Model Accuracy: 57.84%%
# Test model on poison data...
# Attack Success Rate: 0.07%%
# Best test accuaracy 0.5950356012658228 in epoch 21
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 22 took 149.13237953186035 seconds
# ===Epoch: 23/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/500.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.80810 | 0.77719 | 0.01124 |    2.75000 |
# | 341/1024    | 0.59190 | 0.56932 | 0.00809 |    2.79163 |
# | 682/1024    | 1.03330 | 0.98783 | 0.01605 |    2.83325 |
# | 1023/1024   | 0.89438 | 0.85819 | 0.01259 |    2.87488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.71537 | 0.68383 | 0.01121 |    2.81244 | 107.61357 |
# Test model on clean data...
# Clean Data Model Accuracy: 62.04%%
# Test model on poison data...
# Attack Success Rate: 0.04%%
# Best test accuaracy 0.6203520569620253 in epoch 23
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 23 took 148.75340342521667 seconds
# ===Epoch: 24/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/500.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.67449 | 0.65016 | 0.00846 |    2.87500 |
# | 341/1024    | 0.93068 | 0.88638 | 0.01519 |    2.91663 |
# | 682/1024    | 0.67611 | 0.63044 | 0.01544 |    2.95825 |
# | 1023/1024   | 0.45281 | 0.42776 | 0.00835 |    2.99988 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.64578 | 0.61412 | 0.01078 |    2.93744 | 108.47940 |
# Test model on clean data...
# Clean Data Model Accuracy: 61.26%%
# Test model on poison data...
# Attack Success Rate: 0.07%%
# Best test accuaracy 0.6203520569620253 in epoch 23
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 24 took 149.2899386882782 seconds
# ===Epoch: 25/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/500.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.76970 | 0.73026 | 0.01315 |    3.00000 |
# | 341/1024    | 0.12408 | 0.11347 | 0.00349 |    3.04163 |
# | 682/1024    | 0.75986 | 0.71420 | 0.01481 |    3.08325 |
# | 1023/1024   | 0.22676 | 0.21266 | 0.00451 |    3.12488 |
# MixMatch training summary:
# |---------|---------|---------|------------|-----------|
# |    loss |   xloss |   uloss |   lambda_u |      time |
# |---------|---------|---------|------------|-----------|
# | 0.66881 | 0.63528 | 0.01095 |    3.06244 | 107.50642 |
# Test model on clean data...
# Clean Data Model Accuracy: 63.06%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.6306368670886076 in epoch 25
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 25 took 148.4444510936737 seconds
# ===Epoch: 26/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/600.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.87218 | 0.82893 | 0.01384 |    3.12500 |
# | 341/1024    | 0.68341 | 0.65462 | 0.00909 |    3.16663 |
# | 682/1024    | 0.52276 | 0.50443 | 0.00571 |    3.20825 |
# | 1023/1024   | 0.81383 | 0.77722 | 0.01126 |    3.24988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.70255 | 0.66770 | 0.01094 |    3.18744 | 95.81388 |
# Test model on clean data...
# Clean Data Model Accuracy: 64.13%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.641317246835443 in epoch 26
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 26 took 136.72567915916443 seconds
# ===Epoch: 27/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/600.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.42120 | 0.40319 | 0.00554 |    3.25000 |
# | 341/1024    | 0.88103 | 0.84044 | 0.01233 |    3.29163 |
# | 682/1024    | 0.55650 | 0.52970 | 0.00804 |    3.33325 |
# | 1023/1024   | 0.09414 | 0.07764 | 0.00489 |    3.37488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.64629 | 0.61144 | 0.01052 |    3.31244 | 95.37700 |
# Test model on clean data...
# Clean Data Model Accuracy: 63.08%%
# Test model on poison data...
# Attack Success Rate: 0.00%%
# Best test accuaracy 0.641317246835443 in epoch 26
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 27 took 135.9463198184967 seconds
# ===Epoch: 28/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/600.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.95055 | 0.89133 | 0.01755 |    3.37500 |
# | 341/1024    | 0.77399 | 0.73524 | 0.01134 |    3.41663 |
# | 682/1024    | 1.05853 | 0.99743 | 0.01767 |    3.45825 |
# | 1023/1024   | 1.06401 | 1.01163 | 0.01497 |    3.49988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.71015 | 0.67302 | 0.01080 |    3.43744 | 94.96925 |
# Test model on clean data...
# Clean Data Model Accuracy: 64.18%%
# Test model on poison data...
# Attack Success Rate: 0.01%%
# Best test accuaracy 0.6418117088607594 in epoch 28
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 28 took 136.07242798805237 seconds
# ===Epoch: 29/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/600.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.93273 | 0.89126 | 0.01185 |    3.50000 |
# | 341/1024    | 0.61145 | 0.58223 | 0.00825 |    3.54163 |
# | 682/1024    | 0.90309 | 0.85855 | 0.01243 |    3.58325 |
# | 1023/1024   | 1.04787 | 0.98467 | 0.01744 |    3.62488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.65749 | 0.62062 | 0.01035 |    3.56244 | 96.69714 |
# Test model on clean data...
# Clean Data Model Accuracy: 63.00%%
# Test model on poison data...
# Attack Success Rate: 0.23%%
# Best test accuaracy 0.6418117088607594 in epoch 28
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 29 took 137.24885964393616 seconds
# ===Epoch: 30/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/600.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.60908 | 0.57319 | 0.00990 |    3.62500 |
# | 341/1024    | 0.86272 | 0.81476 | 0.01308 |    3.66663 |
# | 682/1024    | 0.88891 | 0.84328 | 0.01231 |    3.70825 |
# | 1023/1024   | 0.52877 | 0.50762 | 0.00564 |    3.74988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.66675 | 0.62851 | 0.01037 |    3.68744 | 96.07038 |
# Test model on clean data...
# Clean Data Model Accuracy: 64.15%%
# Test model on poison data...
# Attack Success Rate: 0.01%%
# Best test accuaracy 0.6418117088607594 in epoch 28
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 30 took 136.8199851512909 seconds
# ===Epoch: 31/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/700.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.27106 | 0.25045 | 0.00550 |    3.75000 |
# | 341/1024    | 1.11651 | 1.05937 | 0.01507 |    3.79163 |
# | 682/1024    | 0.21715 | 0.19923 | 0.00467 |    3.83325 |
# | 1023/1024   | 0.67896 | 0.64702 | 0.00824 |    3.87488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.69916 | 0.65939 | 0.01043 |    3.81244 | 92.45930 |
# Test model on clean data...
# Clean Data Model Accuracy: 64.73%%
# Test model on poison data...
# Attack Success Rate: 0.04%%
# Best test accuaracy 0.6473496835443038 in epoch 31
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 31 took 133.12641716003418 seconds
# ===Epoch: 32/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/700.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.49989 | 0.46841 | 0.00812 |    3.87500 |
# | 341/1024    | 0.74717 | 0.70765 | 0.01009 |    3.91663 |
# | 682/1024    | 0.54469 | 0.52400 | 0.00523 |    3.95825 |
# | 1023/1024   | 0.27134 | 0.25640 | 0.00373 |    3.99988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.65995 | 0.61981 | 0.01020 |    3.93744 | 90.42117 |
# Test model on clean data...
# Clean Data Model Accuracy: 64.95%%
# Test model on poison data...
# Attack Success Rate: 0.10%%
# Best test accuaracy 0.6495253164556962 in epoch 32
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 32 took 131.05800771713257 seconds
# ===Epoch: 33/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/700.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.21186 | 1.15056 | 0.01532 |    4.00000 |
# | 341/1024    | 0.69628 | 0.66039 | 0.00888 |    4.04163 |
# | 682/1024    | 0.15931 | 0.13375 | 0.00626 |    4.08325 |
# | 1023/1024   | 0.82909 | 0.77995 | 0.01191 |    4.12488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.69523 | 0.65424 | 0.01009 |    4.06244 | 92.51562 |
# Test model on clean data...
# Clean Data Model Accuracy: 65.42%%
# Test model on poison data...
# Attack Success Rate: 0.04%%
# Best test accuaracy 0.6541732594936709 in epoch 33
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 33 took 133.30395603179932 seconds
# ===Epoch: 34/120===
# Mining clean data by class-aware loss-guided split...
# 0.0/700.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.04236 | 0.98279 | 0.01444 |    4.12500 |
# | 341/1024    | 0.92841 | 0.85967 | 0.01650 |    4.16663 |
# | 682/1024    | 1.02243 | 0.95278 | 0.01655 |    4.20825 |
# | 1023/1024   | 0.87002 | 0.81518 | 0.01290 |    4.24988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.67926 | 0.63625 | 0.01027 |    4.18744 | 90.96916 |
# Test model on clean data...
# Clean Data Model Accuracy: 65.65%%
# Test model on poison data...
# Attack Success Rate: 1.89%%
# Best test accuaracy 0.6565466772151899 in epoch 34
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 34 took 131.71125173568726 seconds
# ===Epoch: 35/120===
# Mining clean data by class-aware loss-guided split...
# 1.0/700.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.68506 | 0.64406 | 0.00965 |    4.25000 |
# | 341/1024    | 1.06896 | 1.00256 | 0.01547 |    4.29163 |
# | 682/1024    | 0.78435 | 0.74207 | 0.00976 |    4.33325 |
# | 1023/1024   | 0.84151 | 0.79350 | 0.01097 |    4.37488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.65464 | 0.61202 | 0.00988 |    4.31244 | 91.15170 |
# Test model on clean data...
# Clean Data Model Accuracy: 64.47%%
# Test model on poison data...
# Attack Success Rate: 4.27%%
# Best test accuaracy 0.6565466772151899 in epoch 34
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 35 took 132.09784412384033 seconds
# ===Epoch: 36/120===
# Mining clean data by class-aware loss-guided split...
# 1.0/800.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.94763 | 0.89418 | 0.01222 |    4.37500 |
# | 341/1024    | 0.98505 | 0.91539 | 0.01577 |    4.41663 |
# | 682/1024    | 0.79145 | 0.73699 | 0.01222 |    4.45825 |
# | 1023/1024   | 0.75555 | 0.72398 | 0.00702 |    4.49988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.70625 | 0.66130 | 0.01013 |    4.43744 | 85.77227 |
# Test model on clean data...
# Clean Data Model Accuracy: 66.97%%
# Test model on poison data...
# Attack Success Rate: 9.96%%
# Best test accuaracy 0.6696993670886076 in epoch 36
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 36 took 127.03093481063843 seconds
# ===Epoch: 37/120===
# Mining clean data by class-aware loss-guided split...
# 4.0/800.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.07701 | 1.00153 | 0.01677 |    4.50000 |
# | 341/1024    | 0.44457 | 0.41707 | 0.00606 |    4.54163 |
# | 682/1024    | 0.87370 | 0.81530 | 0.01274 |    4.58325 |
# | 1023/1024   | 0.04728 | 0.02504 | 0.00481 |    4.62488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.68422 | 0.63913 | 0.00988 |    4.56244 | 86.08263 |
# Test model on clean data...
# Clean Data Model Accuracy: 68.73%%
# Test model on poison data...
# Attack Success Rate: 12.35%%
# Best test accuaracy 0.6873022151898734 in epoch 37
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 37 took 127.03879427909851 seconds
# ===Epoch: 38/120===
# Mining clean data by class-aware loss-guided split...
# 2.0/800.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.58355 | 0.56260 | 0.00453 |    4.62500 |
# | 341/1024    | 1.02255 | 0.95640 | 0.01417 |    4.66663 |
# | 682/1024    | 1.10372 | 1.04070 | 0.01338 |    4.70825 |
# | 1023/1024   | 0.82328 | 0.76618 | 0.01202 |    4.74988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.72428 | 0.67586 | 0.01033 |    4.68744 | 86.20843 |
# Test model on clean data...
# Clean Data Model Accuracy: 67.71%%
# Test model on poison data...
# Attack Success Rate: 8.66%%
# Best test accuaracy 0.6873022151898734 in epoch 37
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 38 took 127.11709785461426 seconds
# ===Epoch: 39/120===
# Mining clean data by class-aware loss-guided split...
# 1.0/800.0 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.85147 | 0.78252 | 0.01452 |    4.75000 |
# | 341/1024    | 1.00736 | 0.94686 | 0.01263 |    4.79163 |
# ...
# Epoch 93 took 144.65624117851257 seconds
# ===Epoch: 94/120===
# Mining clean data by meta-split...
# 8.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.10955 | 0.08314 | 0.00227 |   11.62500 |
# | 341/1024    | 1.35531 | 1.19152 | 0.01404 |   11.66663 |
# | 682/1024    | 1.35330 | 1.18105 | 0.01471 |   11.70825 |
# | 1023/1024   | 0.94670 | 0.85919 | 0.00745 |   11.74988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.93819 | 0.84027 | 0.00838 |   11.68744 | 54.50009 |
# Test model on clean data...
# Clean Data Model Accuracy: 83.66%%
# Test model on poison data...
# Attack Success Rate: 5.21%%
# Best test accuaracy 0.836629746835443 in epoch 94
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 94 took 144.0073482990265 seconds
# ===Epoch: 95/120===
# Mining clean data by meta-split...
# 29.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.16662 | 1.06155 | 0.00894 |   11.75000 |
# | 341/1024    | 0.59425 | 0.57246 | 0.00185 |   11.79163 |
# | 682/1024    | 1.30667 | 1.14147 | 0.01396 |   11.83325 |
# | 1023/1024   | 1.40201 | 1.20404 | 0.01667 |   11.87488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.93873 | 0.84352 | 0.00806 |   11.81244 | 54.81231 |
# Test model on clean data...
# Clean Data Model Accuracy: 84.58%%
# Test model on poison data...
# Attack Success Rate: 6.57%%
# Best test accuaracy 0.8458267405063291 in epoch 95
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 95 took 144.54371690750122 seconds
# ===Epoch: 96/120===
# Mining clean data by meta-split...
# 32.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.33021 | 0.31617 | 0.00118 |   11.87500 |
# | 341/1024    | 0.99874 | 0.88766 | 0.00932 |   11.91663 |
# | 682/1024    | 0.88677 | 0.81926 | 0.00565 |   11.95825 |
# | 1023/1024   | 0.25304 | 0.21641 | 0.00305 |   11.99988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.96264 | 0.86404 | 0.00826 |   11.93744 | 54.72476 |
# Test model on clean data...
# Clean Data Model Accuracy: 87.53%%
# Test model on poison data...
# Attack Success Rate: 5.06%%
# Best test accuaracy 0.8752966772151899 in epoch 96
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 96 took 144.57070779800415 seconds
# ===Epoch: 97/120===
# Mining clean data by meta-split...
# 2.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.24043 | 1.08719 | 0.01277 |   12.00000 |
# | 341/1024    | 1.60226 | 1.41435 | 0.01560 |   12.04163 |
# | 682/1024    | 0.34379 | 0.30649 | 0.00309 |   12.08325 |
# | 1023/1024   | 0.95354 | 0.86440 | 0.00735 |   12.12488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.94534 | 0.84677 | 0.00817 |   12.06244 | 55.41960 |
# Test model on clean data...
# Clean Data Model Accuracy: 87.09%%
# Test model on poison data...
# Attack Success Rate: 6.65%%
# Best test accuaracy 0.8752966772151899 in epoch 96
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 97 took 144.95389461517334 seconds
# ===Epoch: 98/120===
# Mining clean data by meta-split...
# 74.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.26029 | 1.07889 | 0.01496 |   12.12500 |
# | 341/1024    | 1.24572 | 1.12440 | 0.00997 |   12.16663 |
# | 682/1024    | 0.54979 | 0.50125 | 0.00398 |   12.20825 |
# | 1023/1024   | 1.00894 | 0.90945 | 0.00812 |   12.24988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.95628 | 0.85592 | 0.00823 |   12.18744 | 55.27221 |
# Test model on clean data...
# Clean Data Model Accuracy: 87.55%%
# Test model on poison data...
# Attack Success Rate: 8.78%%
# Best test accuaracy 0.8754944620253164 in epoch 98
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 98 took 144.81728887557983 seconds
# ===Epoch: 99/120===
# Mining clean data by meta-split...
# 31.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.39790 | 1.22849 | 0.01383 |   12.25000 |
# | 341/1024    | 1.16761 | 1.04444 | 0.01002 |   12.29163 |
# | 682/1024    | 1.31267 | 1.15289 | 0.01296 |   12.33325 |
# | 1023/1024   | 1.03852 | 0.94305 | 0.00771 |   12.37488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.92870 | 0.83238 | 0.00782 |   12.31244 | 55.02283 |
# Test model on clean data...
# Clean Data Model Accuracy: 89.26%%
# Test model on poison data...
# Attack Success Rate: 9.25%%
# Best test accuaracy 0.8926028481012658 in epoch 99
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 99 took 144.58420038223267 seconds
# ===Epoch: 100/120===
# Mining clean data by meta-split...
# 26.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.34641 | 1.17848 | 0.01357 |   12.37500 |
# | 341/1024    | 1.20229 | 1.06758 | 0.01085 |   12.41663 |
# | 682/1024    | 1.30401 | 1.14680 | 0.01262 |   12.45825 |
# | 1023/1024   | 1.31579 | 1.14274 | 0.01384 |   12.49988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.92000 | 0.82503 | 0.00764 |   12.43744 | 55.22315 |
# Test model on clean data...
# Clean Data Model Accuracy: 90.08%%
# Test model on poison data...
# Attack Success Rate: 9.25%%
# Best test accuaracy 0.900810917721519 in epoch 100
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 100 took 144.6834671497345 seconds
# ===Epoch: 101/120===
# Mining clean data by meta-split...
# 32.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.32018 | 1.14078 | 0.01435 |   12.50000 |
# | 341/1024    | 1.23161 | 1.06331 | 0.01342 |   12.54163 |
# | 682/1024    | 0.26533 | 0.23946 | 0.00206 |   12.58325 |
# | 1023/1024   | 1.24706 | 1.08533 | 0.01281 |   12.62488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.91259 | 0.81134 | 0.00806 |   12.56244 | 55.35533 |
# Test model on clean data...
# Clean Data Model Accuracy: 90.34%%
# Test model on poison data...
# Attack Success Rate: 6.73%%
# Best test accuaracy 0.9033821202531646 in epoch 101
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 101 took 144.68169856071472 seconds
# ===Epoch: 102/120===
# Mining clean data by meta-split...
# 26.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.23721 | 1.08870 | 0.01176 |   12.62500 |
# | 341/1024    | 0.86432 | 0.82908 | 0.00278 |   12.66663 |
# | 682/1024    | 1.41544 | 1.22856 | 0.01471 |   12.70825 |
# | 1023/1024   | 1.31751 | 1.13967 | 0.01395 |   12.74988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.89973 | 0.80675 | 0.00733 |   12.68744 | 59.17874 |
# Test model on clean data...
# Clean Data Model Accuracy: 91.09%%
# Test model on poison data...
# Attack Success Rate: 6.74%%
# Best test accuaracy 0.9108979430379747 in epoch 102
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 102 took 149.3178825378418 seconds
# ===Epoch: 103/120===
# Mining clean data by meta-split...
# 14.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 1.18003 | 1.03484 | 0.01139 |   12.75000 |
# | 341/1024    | 0.97637 | 0.89899 | 0.00605 |   12.79163 |
# | 682/1024    | 0.20718 | 0.20118 | 0.00047 |   12.83325 |
# | 1023/1024   | 1.11562 | 0.97659 | 0.01080 |   12.87488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.92180 | 0.82528 | 0.00753 |   12.81244 | 55.20994 |
# Test model on clean data...
# Clean Data Model Accuracy: 91.78%%
# Test model on poison data...
# Attack Success Rate: 4.30%%
# Best test accuaracy 0.9178204113924051 in epoch 103
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 103 took 144.52193403244019 seconds
# ===Epoch: 104/120===
# Mining clean data by meta-split...
# 12.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.21607 | 0.19436 | 0.00169 |   12.87500 |
# | 341/1024    | 0.63937 | 0.61873 | 0.00160 |   12.91663 |
# | 682/1024    | 1.11006 | 1.00090 | 0.00842 |   12.95825 |
# | 1023/1024   | 0.50619 | 0.48906 | 0.00132 |   12.99988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.89884 | 0.80754 | 0.00706 |   12.93744 | 55.17212 |
# Test model on clean data...
# Clean Data Model Accuracy: 91.90%%
# Test model on poison data...
# Attack Success Rate: 6.28%%
# Best test accuaracy 0.9190071202531646 in epoch 104
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 104 took 144.51442551612854 seconds
# ===Epoch: 105/120===
# Mining clean data by meta-split...
# 41.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.64745 | 0.61256 | 0.00268 |   13.00000 |
# | 341/1024    | 0.73044 | 0.68497 | 0.00349 |   13.04163 |
# | 682/1024    | 0.49226 | 0.45715 | 0.00268 |   13.08325 |
# | 1023/1024   | 0.92575 | 0.84489 | 0.00616 |   13.12488 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.87407 | 0.78786 | 0.00660 |   13.06244 | 55.54217 |
# Test model on clean data...
# Clean Data Model Accuracy: 92.26%%
# Test model on poison data...
# Attack Success Rate: 7.53%%
# Best test accuaracy 0.922567246835443 in epoch 105
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 105 took 145.1472682952881 seconds
# ===Epoch: 106/120===
# Mining clean data by meta-split...
# 45.0/25000 poisoned samples in clean data pool
# MixMatch training...
# |-------------|---------|---------|---------|------------|
# | Iteration   |    loss |   xloss |   uloss |   lambda_u |
# |-------------|---------|---------|---------|------------|
# | 0/1024      | 0.67115 | 0.64264 | 0.00217 |   13.12500 |
# | 341/1024    | 0.38491 | 0.34252 | 0.00322 |   13.16663 |
# | 682/1024    | 1.34040 | 1.16688 | 0.01314 |   13.20825 |
# | 1023/1024   | 1.36168 | 1.17772 | 0.01388 |   13.24988 |
# MixMatch training summary:
# |---------|---------|---------|------------|----------|
# |    loss |   xloss |   uloss |   lambda_u |     time |
# |---------|---------|---------|------------|----------|
# | 0.90690 | 0.81178 | 0.00721 |   13.18744 | 55.45062 |
# Test model on clean data...
# Clean Data Model Accuracy: 92.41%%
# Test model on poison data...
# Attack Success Rate: 4.69%%
# Best test accuaracy 0.9240506329113924 in epoch 106
# Save the best model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/best_model_30_6.pt
# Save the latest model to /gpfs0/bgu-benshimo/users/guyperet/ASD/storage/sig_test_20_6/checkpoint/latest_model_30_6.pt
# Epoch 106 took 144.78665709495544 seconds
# ===Epoch: 107/120===

# %% [markdown]
# ## Testing

# %%
PARAMS = {"sig_test": [(5, 4), (5, 8), (10, 4), (10, 10), (20, 6), (20, 12)],
          "invisible_grid_attack": [(4, 4), (4, 16), (8, 8), (16, 4), (16, 16), (32, 32)],
          "smooth_poison": [(4, 15), (5, 5), (8, 15), (15, 3), (15, 7), (15, 15)]}

for ATTACK_TYPE in ["sig_test", "invisible_grid_attack", "smooth_poison"]:
    curr_params = PARAMS[ATTACK_TYPE]
    for param in curr_params:
        print(f"\n🔍 Running testing for {ATTACK_TYPE} attack with parameters ({param[0]}, {param[1]})...")
        model_path = f'latest_model_{param[0]}_{param[1]}.pt'
        config_path = f'./config/{ATTACK_TYPE}_{param[0]}_{param[1]}.yaml'
        run_testing(model_path, config_path)
# Out:
# 🔍 Running testing for sig_test attack with parameters (5, 4)...
# Start at: Sat Feb  1 13:24:45 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 92.47%%
# Test model on poison data...
# Attack Success Rate: 91.27%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for sig_test attack with parameters (5, 8)...
# Start at: Sat Feb  1 13:25:04 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.58%%
# Test model on poison data...
# Attack Success Rate: 3.12%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for sig_test attack with parameters (10, 4)...
# Start at: Sat Feb  1 13:25:16 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.83%%
# Test model on poison data...
# Attack Success Rate: 99.79%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for sig_test attack with parameters (10, 10)...
# Start at: Sat Feb  1 13:25:26 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.71%%
# Test model on poison data...
# Attack Success Rate: 1.49%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for sig_test attack with parameters (20, 6)...
# Start at: Sat Feb  1 13:25:41 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 92.87%%
# Test model on poison data...
# Attack Success Rate: 3.37%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for sig_test attack with parameters (20, 12)...
# Start at: Sat Feb  1 13:25:56 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.38%%
# Test model on poison data...
# Attack Success Rate: 1.41%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for invisible_grid_attack attack with parameters (4, 4)...
# Start at: Sat Feb  1 13:26:07 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 92.86%%
# Test model on poison data...
# Attack Success Rate: 56.29%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for invisible_grid_attack attack with parameters (4, 16)...
# Start at: Sat Feb  1 13:26:16 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 92.17%%
# Test model on poison data...
# Attack Success Rate: 12.11%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for invisible_grid_attack attack with parameters (8, 8)...
# Start at: Sat Feb  1 13:26:25 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 92.92%%
# Test model on poison data...
# Attack Success Rate: 80.24%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for invisible_grid_attack attack with parameters (16, 4)...
# Start at: Sat Feb  1 13:26:35 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 89.55%%
# Test model on poison data...
# Attack Success Rate: 99.98%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for invisible_grid_attack attack with parameters (16, 16)...
# Start at: Sat Feb  1 13:26:44 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.37%%
# Test model on poison data...
# Attack Success Rate: 49.56%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for invisible_grid_attack attack with parameters (32, 32)...
# Start at: Sat Feb  1 13:26:53 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.43%%
# Test model on poison data...
# Attack Success Rate: 2.67%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for smooth_poison attack with parameters (4, 15)...
# Start at: Sat Feb  1 13:27:03 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 92.74%%
# Test model on poison data...
# Attack Success Rate: 89.17%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for smooth_poison attack with parameters (5, 5)...
# Start at: Sat Feb  1 13:27:13 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.40%%
# Test model on poison data...
# Attack Success Rate: 5.20%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for smooth_poison attack with parameters (8, 15)...
# Start at: Sat Feb  1 13:27:22 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.51%%
# Test model on poison data...
# Attack Success Rate: 3.24%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for smooth_poison attack with parameters (15, 3)...
# Start at: Sat Feb  1 13:27:32 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.31%%
# Test model on poison data...
# Attack Success Rate: 2.92%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for smooth_poison attack with parameters (15, 7)...
# Start at: Sat Feb  1 13:27:43 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.40%%
# Test model on poison data...
# Attack Success Rate: 2.15%%
# ✅ Testing completed!
#
#
# 🔍 Running testing for smooth_poison attack with parameters (15, 15)...
# Start at: Sat Feb  1 13:27:58 2025 at: vscode-guy-0-8
# Test model on clean data...
# Clean Data Model Accuracy: 93.30%%
# Test model on poison data...
# Attack Success Rate: 2.94%%
# ✅ Testing completed!
